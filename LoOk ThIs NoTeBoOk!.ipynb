# %%
import selenium

# %%
video_capture.release()

# %%
pip install PyAutoGUI
# Out:
# ...
#   Using cached PyAutoGUI-0.9.53.tar.gz (59 kB)
# ...
#   Using cached PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached PyTweening-1.0.3.zip (15 kB)
# ...
#   Using cached PyScreeze-0.1.27.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached PyGetWindow-0.0.9.tar.gz (9.7 kB)
# ...
#   Using cached MouseInfo-0.1.3.tar.gz (10 kB)
# ...
#      |████████████████████████████████| 293 kB 4.4 MB/s eta 0:00:01
# ...
#   Using cached PyRect-0.1.4.tar.gz (15 kB)
# ...
#   Using cached pyperclip-1.8.2.tar.gz (20 kB)
# ...
#   Using cached rubicon_objc-0.4.0-py3-none-any.whl (53 kB)
# ...
#      |████████████████████████████████| 273 kB 27.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 143 kB 21.6 MB/s eta 0:00:01
# ...

# %%
import pyautogui, time
# pyautogui.press('space')
def play_pause():
    pyautogui.press('space')

# %%
pwd
# Out:
# '/Users/roryfahy/Programming/projects/LoOk-ThIs-WaY-'

# %%
import cv2
import sys

cascPath = 'haarcascade_frontalface_default.xml'
# faceCascade = cv2.CascadeClassifier(cascPath)
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + cascPath)
# eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
time.sleep(3)
video_capture = cv2.VideoCapture(0)
yes_face, no_face = 0, 0
pause = False
while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
#         flags=cv2.CV_HAAR_SCALE_IMAGE
        flags = cv2.CASCADE_SCALE_IMAGE
    )

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
    if type(faces) != tuple:
        no_face = 0
        yes_face += 1
#         print(f"({yes_face}) Sexy Found")
        face_detected = True
    else:
        yes_face = 0
        no_face += 1
#         print(f"({no_face}) No Sexy Found")
        face_detected = False
    
    
    if no_face == 15 and pause is False:
        print("PAUSE!!!!!")
        play_pause()
        pause = True

    if pause is True and yes_face == 10:
        print("play!!!!!")
        play_pause()
        pause = False


#     eyes = eye_cascade.detectMultiScale(
#         gray,
#         scaleFactor=1.1,
#         minNeighbors=5,
#         minSize=(30, 30),
# #         flags=cv2.CV_HAAR_SCALE_IMAGE
#         flags = cv2.CASCADE_SCALE_IMAGE
#     )

#     # Draw a circl around the eyes
#     for (x, y, w, h) in eyes:
#         cv2.circle(frame, (x, y), h, (0, 255, 0), 2)

#     Display the resulting frameq
    cv2.imshow('Video', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything is done, release the capture
video_capture.release()
cv2.destroyAllWindows()
# Out:
# PAUSE!!!!!
# play!!!!!
# PAUSE!!!!!
# play!!!!!
# PAUSE!!!!!
# play!!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-83f314950907> in <module>
#      16     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      17
# ---> 18     faces = faceCascade.detectMultiScale(
#      19         gray,
#      20         scaleFactor=1.1,
#
# KeyboardInterrupt:

# %%
pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2
# ERROR: No matching distribution found for cv2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 42.6 MB 24.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
